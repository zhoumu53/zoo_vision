# %%
import cv2
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
video = cv2.VideoCapture(
    "/media/dherrera/ElephantExternal/elephants/night_sarah/zurich/2024/ELP - Sandbox_ohne_MGMT/20240803PM/ELP - Sandbox_ohne_MGMT-20240803-221223-1722715943811-7.mp4"
)
_, im = video.read()
plt.imshow(im)

# %%
area = im[0:200, 0:800, :]
plt.imshow(area)

# %%
import pytesseract

pytesseract.image_to_string(area)
# Out:
# '03-08-2024 22:12:23\n'
